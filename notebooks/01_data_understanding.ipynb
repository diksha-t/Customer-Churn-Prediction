# %%
import pandas as pd
import numpy as np 

pd.set_option("display.max_columns", None)

# %%
import os
print(os.getcwd())
print(os.listdir("../data/raw"))
# Out:
# d:\Customer Churn Prediction\notebooks
# ['Telco_Customer_Churn-original.xlsx', 'Telco_Customer_Churn.csv']

# %%
df = pd.read_csv(r"D:\Customer Churn Prediction\data\raw\Telco_Customer_Churn.csv")
